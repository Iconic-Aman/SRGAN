# %% [markdown]
# ## Data Fetching

# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt
from PIL import Image
import random
import numpy as np
import pandas as pd
from keras import layers, Model
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Conv2D, PReLU, LeakyReLU, BatchNormalization, Flatten
from keras.layers import UpSampling2D, Dense, Input , Add
from keras.applications import VGG19
from keras.models import load_model
from tqdm import tqdm

# %%
img_path  = 'mirflickr400'
print(os.listdir(img_path))
# Out:
# ['large_img', 'small_img']

# %%
large_img_dir = os.listdir('mirflickr400/large_img')
large_data_25 = large_img_dir[:25]
large_data_25
# Out:
# ['large1001.jpg',
#  'large1002.jpg',
#  'large1003.jpg',
#  'large1004.jpg',
#  'large1005.jpg',
#  'large1006.jpg',
#  'large1007.jpg',
#  'large1008.jpg',
#  'large1009.jpg',
#  'large1010.jpg',
#  'large1011.jpg',
#  'large1012.jpg',
#  'large1013.jpg',
#  'large1014.jpg',
#  'large1015.jpg',
#  'large1016.jpg',
#  'large1017.jpg',
#  'large1018.jpg',
#  'large1019.jpg',
#  'large1020.jpg',
#  'large1021.jpg',
#  'large1022.jpg',
#  'large1023.jpg',
#  'large1024.jpg',
#  'large1025.jpg']

# %%
def show_img(path):
    img = Image.open(path)
    plt.imshow(img)

# %%
from random import randint
val = randint(1, 20)
img_path = 'mirflickr400/large_img/' + large_data_25[val]
show_img(img_path)

# %%
#making residual blocks
def res_blocks(input):
    x = Conv2D(64, (3,3),  padding='same')(input)
    x = keras.layers.BatchNormalization(momentum=0.5)(x)
    x = keras.layers.PReLU(shared_axes=[1,2])(x)
    
    x = keras.layers.Conv2D(64, (3,3) , padding= 'same')(x)
    x = keras.layers.BatchNormalization(momentum=0.5)(x)
    return keras.layers.add([input, x])

def upscale_block(ip):
    up_model = Conv2D(256, (3,3), 1, padding='same')(ip)
    up_model = keras.layers.UpSampling2D(size= 2)(up_model)
    up_model = keras.layers.PReLU(shared_axes=[1,2])(up_model)
    return up_model

# %% [markdown]
# ## Generator

# %%
#Make Generator
def Generator(input, num_res_blocks):
    layer = keras.layers.Conv2D(64, (9,9),  padding= 'same')(input)
    layer = keras.layers.PReLU(shared_axes=[1,2])(layer)
    # keep this layer into temp variable
    temp = layer
    # add residual blocks
    for i in range(num_res_blocks):
        layer = res_blocks(layer)
    layer = keras.layers.Conv2D(64, (3, 3), 1, padding= 'same')(layer)
    layer = keras.layers.BatchNormalization(momentum=0.5)(layer)
    layer = keras.layers.add([layer, temp])
    
    #add two upscale blocks
    layer = upscale_block(layer)
    layer = upscale_block(layer)
    output = keras.layers.Conv2D(3, (9,9), 1, padding='same')(layer)
    return Model(input, output)

# %% [markdown]
# ## Descriminator

# %%
# make descriminator
def descriminator_block(input, n, strides, bn= True):
    layer = Conv2D(n, (3,3), strides=strides, padding= 'same')(input)
    if bn:
        layer = keras.layers.BatchNormalization(momentum=0.5)(layer)
    layer = keras.layers.LeakyReLU(0.5)(layer)
    return layer

# %%
def Descriminator(input):
    n = 64
    d1 = descriminator_block(input, n, 1, bn=False)
    d2 = descriminator_block(d1, n, 2)
    d3 = descriminator_block(d2, n*2, 1)
    d4 = descriminator_block(d3, n*2, 2)
    d5 = descriminator_block(d4, n*4, 1)
    d6 = descriminator_block(d5, n*4, 2)
    d7 = descriminator_block(d6, n*8, 1)
    d8 = descriminator_block(d7, n*8, 2)
    d8_5 = keras.layers.Flatten()(d8)
    d9 = keras.layers.Dense(n*16)(d8_5)
    d10 = keras.layers.LeakyReLU(negative_slope=0.2)(d9)
    output = keras.layers.Dense(1, activation='sigmoid')(d10) # why sigmoid ->  descriminator is a binary classifier 
    
    return Model(input, output)

# %% [markdown]
# ## combined Model

# %%
# Build vgg for feature extraction
def build_vgg(hr_shape):
    vgg = keras.applications.VGG19(include_top= False, weights= 'imagenet', input_shape= hr_shape)
    return Model(inputs = vgg.inputs, outputs = vgg.layers[10].output)

# %%
def create_Comb(Generator, Descriminator, vgg, lr_img, hr_img):
    gen_img = Generator(lr_img)
    #make image features using VGG
    gen_features = vgg(gen_img)
    Descriminator.trainable = False
    validity = Descriminator(gen_img)
    return keras.Model(inputs= [lr_img, hr_img], outputs = [validity, gen_features] )

# %%
n = 5000
lr_list = os.listdir('mirflickr400/small_img')
lr_images = []
for img in lr_list:
    path = os.path.join('mirflickr400/small_img', img)
    img = cv.imread(path)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    lr_images.append(img)

# %%
hr_list = os.listdir('mirflickr400/large_img')
hr_images = []
for img in hr_list:
    path = os.path.join('mirflickr400/large_img', img)
    img = cv.imread(path)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    hr_images.append(img)

# %%
len(lr_images), len(hr_images)
# Out:
# (400, 400)

# %%
# lr_images = lr_images[:1000]
# hr_images = hr_images[:1000]

# %%
len(lr_images), len(hr_images)
# Out:
# (400, 400)

# %%
#Converting  list to np.array
lr_images = np.array(lr_images)
hr_images = np.array(hr_images)

# %%
lr_images[0]
# Out:
# array([[[149, 103,  69],
#         [148, 104,  65],
#         [145, 107,  62],
#         ...,
#         [186, 158, 119],
#         [195, 154,  98],
#         [197, 152,  85]],
#
#        [[146, 103,  68],
#         [149, 110,  71],
#         [151, 114,  69],
#         ...,
#         [180, 156, 122],
#         [195, 158, 103],
#         [195, 152,  84]],
#
#        [[147, 111,  75],
#         [152, 119,  78],
#         [152, 121,  74],
#         ...,
#         [190, 172, 148],
#         [188, 155, 102],
#         [201, 161,  92]],
#
#        ...,
#
#        [[139,  97,  47],
#         [144, 103,  51],
#         [152, 111,  55],
#         ...,
#         [145,  88,  58],
#         [218, 170, 121],
#         [212, 170, 110]],
#
#        [[144, 102,  54],
#         [150, 110,  59],
#         [146, 106,  54],
#         ...,
#         [102,  49,  18],
#         [206, 158, 109],
#         [214, 170, 109]],
#
#        [[139,  97,  49],
#         [149, 109,  58],
#         [141, 104,  52],
#         ...,
#         [ 82,  33,   3],
#         [182, 134,  85],
#         [216, 170, 110]]], dtype=uint8)

# %%
def show_lr_and_hr_img(index):
    plt.figure(figsize=(10,6))
    plt.subplot(121)
    plt.title('Low Res Image')
    plt.imshow(np.reshape(lr_images[index], (32, 32, 3)))  
    plt.axis('off')
    plt.subplot(122)
    plt.imshow(np.reshape(hr_images[index], (128, 128, 3)))
    plt.title('High Res Image')
    plt.axis('off')

# %%
index = randint(0, len(lr_images)-1)
show_lr_and_hr_img(index)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Scaling Images

# %%
lr_images = (lr_images/255).astype(np.float32)
hr_images = (hr_images/255).astype(np.float32)

# %%
hr_images[0]
# Out:
# array([[[0.53333336, 0.3882353 , 0.21176471],
#         [0.54901963, 0.40392157, 0.22745098],
#         [0.5411765 , 0.39607844, 0.21960784],
#         ...,
#         [0.76862746, 0.6039216 , 0.3137255 ],
#         [0.77254903, 0.5882353 , 0.3137255 ],
#         [0.8       , 0.6156863 , 0.34117648]],
#
#        [[0.53333336, 0.3882353 , 0.21568628],
#         [0.5568628 , 0.4117647 , 0.23529412],
#         [0.54901963, 0.40392157, 0.23137255],
#         ...,
#         [0.77254903, 0.6       , 0.32156864],
#         [0.7647059 , 0.5882353 , 0.32156864],
#         [0.78431374, 0.6       , 0.33333334]],
#
#        [[0.5411765 , 0.39607844, 0.23137255],
#         [0.5647059 , 0.41960785, 0.24705882],
#         [0.54901963, 0.40392157, 0.23921569],
#         ...,
#         [0.78431374, 0.60784316, 0.34509805],
#         [0.7764706 , 0.59607846, 0.3529412 ],
#         [0.78039217, 0.6       , 0.35686275]],
#
#        ...,
#
#        [[0.49411765, 0.3372549 , 0.19607843],
#         [0.54509807, 0.39215687, 0.23921569],
#         [0.50980395, 0.35686275, 0.1882353 ],
#         ...,
#         [0.8666667 , 0.65882355, 0.44705883],
#         [0.85490197, 0.6627451 , 0.44313726],
#         [0.85882354, 0.6666667 , 0.44705883]],
#
#        [[0.52156866, 0.36862746, 0.21568628],
#         [0.49803922, 0.34509805, 0.18431373],
#         [0.52156866, 0.36862746, 0.20784314],
#         ...,
#         [0.8666667 , 0.65882355, 0.45490196],
#         [0.8509804 , 0.654902  , 0.44705883],
#         [0.84313726, 0.65882355, 0.44705883]],
#
#        [[0.5137255 , 0.36078432, 0.2       ],
#         [0.5137255 , 0.36078432, 0.2       ],
#         [0.5254902 , 0.37254903, 0.21176471],
#         ...,
#         [0.87058824, 0.6627451 , 0.45882353],
#         [0.8509804 , 0.654902  , 0.44705883],
#         [0.8352941 , 0.6509804 , 0.4392157 ]]], dtype=float32)

# %% [markdown]
# #### Data Splitting

# %%
lr_train, lr_test, hr_train, hr_test = train_test_split(lr_images, hr_images, test_size=0.3,  random_state= 100)

# %%
lr_train.shape, lr_test.shape, hr_train.shape, hr_test.shape
# Out:
# ((280, 32, 32, 3), (120, 32, 32, 3), (280, 128, 128, 3), (120, 128, 128, 3))

# %%
#get lr and hr shape
lr_shape = (lr_train.shape[1], lr_train.shape[2], lr_train.shape[3])
hr_shape = (hr_train.shape[1], hr_train.shape[2], hr_train.shape[3])
lr_shape, hr_shape
# Out:
# ((32, 32, 3), (128, 128, 3))

# %%
lr_ip = Input(shape= lr_shape)
hr_ip = Input(shape= hr_shape)
lr_ip, hr_ip
# Out:
# (<KerasTensor shape=(None, 32, 32, 3), dtype=float32, sparse=None, name=keras_tensor>,
#  <KerasTensor shape=(None, 128, 128, 3), dtype=float32, sparse=None, name=keras_tensor_1>)

# %% [markdown]
# ## Model Building

# %%
generator = Generator(input= lr_ip, num_res_blocks= 16)

# %%
generator.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │     15,616 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu (PReLU)     │ (None, 32, 32,    │         64 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │     36,928 │ p_re_lu[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_1 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │     36,928 │ p_re_lu_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ p_re_lu[0][0],    │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │     36,928 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_2 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     36,928 │ p_re_lu_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ add[0][0],        │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │     36,928 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_3 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     36,928 │ p_re_lu_3[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ add_1[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │     36,928 │ add_2[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_4 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │     36,928 │ p_re_lu_4[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 32, 32,    │          0 │ add_2[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 32,    │     36,928 │ add_3[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_5 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 32, 32,    │          0 │ add_3[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_4[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_6 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 32, 32,    │          0 │ add_4[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_5[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_7 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_7[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 32, 32,    │          0 │ add_5[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_6[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_8 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_8[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 32, 32,    │          0 │ add_6[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_7[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_9 (PReLU)   │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_9[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 32, 32,    │          0 │ add_7[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_8[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_10 (PReLU)  │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_10[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 32, 32,    │          0 │ add_8[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_9[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_11 (PReLU)  │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_11[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 32, 32,    │          0 │ add_9[0][0],      │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_10[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_12 (PReLU)  │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_12[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 32, 32,    │          0 │ add_10[0][0],     │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_11[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_13 (PReLU)  │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_13[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 32, 32,    │          0 │ add_11[0][0],     │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_12[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_14 (PReLU)  │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_14[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 32, 32,    │          0 │ add_12[0][0],     │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_13[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_15 (PReLU)  │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_15[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 32, 32,    │          0 │ add_13[0][0],     │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_14[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_16 (PReLU)  │ (None, 32, 32,    │         64 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 32, 32,    │     36,928 │ p_re_lu_16[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 32, 32,    │          0 │ add_14[0][0],     │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 32, 32,    │     36,928 │ add_15[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ p_re_lu[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 32, 32,    │    147,712 │ add_16[0][0]      │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 64,    │          0 │ conv2d_34[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_17 (PReLU)  │ (None, 64, 64,    │        256 │ up_sampling2d[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │    590,080 │ p_re_lu_17[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 128,  │          0 │ conv2d_35[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ p_re_lu_18 (PReLU)  │ (None, 128, 128,  │        256 │ up_sampling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 128, 128,  │     62,211 │ p_re_lu_18[0][0]  │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,044,291 (7.80 MB)
#  Trainable params: 2,040,067 (7.78 MB)
#  Non-trainable params: 4,224 (16.50 KB)

# %%
discriminator = Descriminator(hr_ip)
discriminator.compile('adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
discriminator.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_33          │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_34          │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_35          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_36          │ (None, 32, 32, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_37          │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 16, 16, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 16, 16, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_44 (Conv2D)              │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_39          │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │    33,555,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,249,281 (145.91 MB)
#  Trainable params: 38,245,569 (145.90 MB)
#  Non-trainable params: 3,712 (14.50 KB)

# %%
vgg= build_vgg(hr_shape)
print(vgg.summary())
vgg.trainable = False
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,325,568 (8.87 MB)
#  Trainable params: 2,325,568 (8.87 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
GAN_MODEL = create_Comb(generator, discriminator, vgg, lr_ip, hr_ip) 
GAN_MODEL.compile(optimizer= 'adam', loss= ['binary_crossentropy', 'mse'], loss_weights= [1e-3, 1])

# %%
GAN_MODEL.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_1        │ (None, 128, 128,  │  2,044,291 │ input_layer[0][0] │
# │ (Functional)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_3        │ (None, 1)         │ 38,249,281 │ functional_1[0][… │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_5        │ (None, 32, 32,    │  2,325,568 │ functional_1[0][… │
# │ (Functional)        │ 256)              │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 42,619,140 (162.58 MB)
#  Trainable params: 2,040,067 (7.78 MB)
#  Non-trainable params: 40,579,073 (154.80 MB)

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Define Batch

# %%
#create a list of images for hr and lr in batches 
batch_size = 1
train_lr_batch = []
train_hr_batch = []
for it in range(int(hr_train.shape[0]/ batch_size)):
    start_idx = it* batch_size
    end_idx = start_idx + batch_size
    train_hr_batch.append(hr_train[start_idx: end_idx])
    train_lr_batch.append(lr_train[start_idx: end_idx])

# %%
EPOCH = 5
for e in range(EPOCH):
    fake_label = np.zeros((batch_size, 1)) #assign a label of zero to all fake images
    real_label = np.ones((batch_size, 1))  #assign a label of ones to all fake images
    # Create empty Lists to populate gen and disc losses.
    g_losses = []
    d_losses = []

    #Enumerate training over batches
    for b in tqdm(range(len(train_hr_batch))):
        lr_imgs =  train_lr_batch[b]
        hr_imgs =  train_hr_batch[b]
        
        fake_imgs = generator.predict_on_batch(lr_imgs)
        
        ##First, train the discriminator on fake and real HR images.
        discriminator.trainable = True
        d_loss_gen = discriminator.train_on_batch(fake_imgs, fake_label)
        d_loss_real = discriminator.train_on_batch(hr_imgs, real_label)
        
        # Now, train the generator by fixing discriminator as non-trainoble
        discriminator.trainable = False 
        
        d_loss = 0.5 * np.add(d_loss_real, d_loss_gen)
        
        # Extract VGG features, to be used towards calculating loss
        image_features = vgg.predict(hr_imgs)
        
        #train the Generator via GAN 
        # Remember that we have 2 Losses,adversarial Loss and content (VGG) Loss
        
        g_loss, _, _ = GAN_MODEL.train_on_batch([lr_imgs, hr_imgs], [real_label, image_features])

        #save loss to a list so we can average
        d_losses.append(d_loss)
        g_losses.append(g_loss)

    # Convert the List of Losses to an array to make it easy to average
    g_losses = np.array(g_losses)
    d_losses = np.array(d_losses)
    
    g_loss = np.sum(g_losses, axis = 0) / len(g_losses)
    d_loss = np.sum(d_losses, axis = 0) / len(d_losses)

    #report the progress during training
    print('epoch:', e+1, 'g_loss:', g_loss, 'd_loss:', d_loss)
    if (e+1) % 1 == 0:
        # Save the generator after every n epochs (Usually 5 epocns)
        generator.save("model"+ str(e+1) +".h5")
# Out:
#   0%|          | 0/280 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
#   0%|          | 1/280 [00:44<3:25:33, 44.21s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 19
#      17 discriminator.trainable = True
#      18 d_loss_gen = discriminator.train_on_batch(fake_imgs, fake_label)
# ---> 19 d_loss_real = discriminator.train_on_batch(hr_imgs, real_label)
#      21 # Now, train the generator by fixing discriminator as non-trainoble
#      22 discriminator.trainable = False
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:540, in TensorFlowTrainer.train_on_batch(self, x, y, sample_weight, class_weight, return_dict)
#     537 def data():
#     538     yield (x, y, sample_weight)
# --> 540 logs = self.train_function(data())
#     541 logs = tree.map_structure(lambda x: np.array(x), logs)
#     542 if return_dict:
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\raunak\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Model Testing

# %%
model1 = load_model('model\model1.h5', compile = False)
# model2 = load_model('model\model2.h5', compile = False)
# model3 = load_model('model\model3.h5', compile = False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\raunak\AppData\Local\Temp\ipykernel_6328\154571612.py:1: SyntaxWarning: invalid escape sequence '\m'
#   model1 = load_model('model\model1.h5', compile = False)
# C:\Users\raunak\AppData\Local\Temp\ipykernel_6328\154571612.py:2: SyntaxWarning: invalid escape sequence '\m'
#   model2 = load_model('model\model2.h5', compile = False)
# C:\Users\raunak\AppData\Local\Temp\ipykernel_6328\154571612.py:3: SyntaxWarning: invalid escape sequence '\m'
#   model3 = load_model('model\model3.h5', compile = False)
# C:\Users\raunak\AppData\Local\Temp\ipykernel_6328\154571612.py:1: SyntaxWarning: invalid escape sequence '\m'
#   model1 = load_model('model\model1.h5', compile = False)
# C:\Users\raunak\AppData\Local\Temp\ipykernel_6328\154571612.py:2: SyntaxWarning: invalid escape sequence '\m'
#   model2 = load_model('model\model2.h5', compile = False)
# C:\Users\raunak\AppData\Local\Temp\ipykernel_6328\154571612.py:3: SyntaxWarning: invalid escape sequence '\m'
#   model3 = load_model('model\model3.h5', compile = False)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 model1 = load_model('model\model1.h5', compile = False)
#       2 model2 = load_model('model\model2.h5', compile = False)
#       3 model3 = load_model('model\model3.h5', compile = False)
#
# File c:\Users\raunak\Desktop\SRGAN-master\SRGAN\venv\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File c:\Users\raunak\Desktop\SRGAN-master\SRGAN\venv\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:116, in load_model_from_hdf5(filepath, custom_objects, compile)
#     114 opened_new_file = not isinstance(filepath, h5py.File)
#     115 if opened_new_file:
# --> 116     f = h5py.File(filepath, mode="r")
#     117 else:
#     118     f = filepath
#
# File c:\Users\raunak\Desktop\SRGAN-master\SRGAN\venv\Lib\site-packages\h5py\_hl\files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File c:\Users\raunak\Desktop\SRGAN-master\SRGAN\venv\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'model\model1.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
[x1, x2]= [lr_test, hr_test]
x1, x2
# Out:
# (array([[[[0.9843137 , 1.        , 1.        ],
#           [0.9843137 , 1.        , 1.        ],
#           [0.972549  , 0.98039216, 1.        ],
#           ...,
#           [0.49411765, 0.53333336, 0.49803922],
#           [0.5019608 , 0.50980395, 0.49019608],
#           [0.50980395, 0.5137255 , 0.49411765]],
#
#          [[0.9843137 , 1.        , 0.99607843],
#           [0.96862745, 0.99607843, 1.        ],
#           [0.96862745, 0.99215686, 1.        ],
#           ...,
#           [0.49411765, 0.52156866, 0.49019608],
#           [0.49803922, 0.50980395, 0.48235294],
#           [0.50980395, 0.5137255 , 0.48235294]],
#
#          [[0.99607843, 1.        , 0.98039216],
#           [0.972549  , 1.        , 1.        ],
#           [0.8509804 , 0.91764706, 1.        ],
#           ...,
#           [0.5058824 , 0.5176471 , 0.49019608],
#           [0.50980395, 0.50980395, 0.4627451 ],
#           [0.5137255 , 0.5176471 , 0.4627451 ]],
#
#          ...,
#
#          [[0.33333334, 0.        , 0.35686275],
#           [0.29803923, 0.        , 0.31764707],
#           [0.29411766, 0.05882353, 0.3019608 ],
#           ...,
#           [0.6745098 , 0.6627451 , 0.76862746],
#           [0.9019608 , 0.92941177, 1.        ],
#           [0.13333334, 0.1764706 , 0.43529412]],
#
#          [[0.30980393, 0.        , 0.36078432],
#           [0.33333334, 0.03529412, 0.39215687],
#           [0.28235295, 0.00784314, 0.3529412 ],
#           ...,
#           [0.92941177, 0.95686275, 1.        ],
#           [0.17254902, 0.23137255, 0.49411765],
#           [0.65882355, 0.7372549 , 1.        ]],
#
#          [[0.30980393, 0.01568628, 0.38039216],
#           [0.3019608 , 0.00784314, 0.38039216],
#           [0.3254902 , 0.02352941, 0.42352942],
#           ...,
#           [0.91764706, 0.9607843 , 1.        ],
#           [0.19215687, 0.27058825, 0.5568628 ],
#           [0.09019608, 0.1882353 , 0.5529412 ]]],
#
#
#         [[[0.12941177, 0.15686275, 0.1882353 ],
#           [0.07058824, 0.09803922, 0.12941177],
#           [0.0627451 , 0.08627451, 0.13333334],
#           ...,
#           [0.01960784, 0.1254902 , 0.20784314],
#           [0.03529412, 0.13333334, 0.2509804 ],
#           [0.03529412, 0.13333334, 0.25490198]],
#
#          [[0.07058824, 0.09803922, 0.12941177],
#           [0.03137255, 0.05882353, 0.09019608],
#           [0.01176471, 0.03921569, 0.07843138],
#           ...,
#           [0.00392157, 0.10196079, 0.18039216],
#           [0.00392157, 0.09803922, 0.2       ],
#           [0.04705882, 0.14117648, 0.2509804 ]],
#
#          [[0.04705882, 0.07450981, 0.11372549],
#           [0.        , 0.01176471, 0.04313726],
#           [0.01568628, 0.03137255, 0.06666667],
#           ...,
#           [0.        , 0.09019608, 0.15294118],
#           [0.00784314, 0.09803922, 0.16862746],
#           [0.04313726, 0.12941177, 0.21176471]],
#
#          ...,
#
#          [[0.02352941, 0.01568628, 0.06666667],
#           [0.03529412, 0.03137255, 0.08627451],
#           [0.03921569, 0.04313726, 0.11372549],
#           ...,
#           [0.01176471, 0.03137255, 0.11764706],
#           [0.04313726, 0.08627451, 0.16470589],
#           [0.03137255, 0.08235294, 0.14901961]],
#
#          [[0.00784314, 0.        , 0.04313726],
#           [0.01568628, 0.01568628, 0.0627451 ],
#           [0.01176471, 0.01568628, 0.08627451],
#           ...,
#           [0.01960784, 0.03529412, 0.13333334],
#           [0.03529412, 0.07843138, 0.15686275],
#           [0.03529412, 0.08627451, 0.16078432]],
#
#          [[0.00784314, 0.00392157, 0.03529412],
#           [0.01176471, 0.01176471, 0.05098039],
#           [0.        , 0.00392157, 0.07450981],
#           ...,
#           [0.00784314, 0.02352941, 0.12156863],
#           [0.        , 0.03137255, 0.11764706],
#           [0.00392157, 0.05490196, 0.12941177]]],
#
#
#         [[[0.21176471, 0.14901961, 0.09803922],
#           [0.24705882, 0.18431373, 0.13333334],
#           [0.3529412 , 0.28235295, 0.22745098],
#           ...,
#           [0.34117648, 0.3019608 , 0.2627451 ],
#           [0.5647059 , 0.5254902 , 0.49019608],
#           [0.43137255, 0.39215687, 0.35686275]],
#
#          [[0.2627451 , 0.2       , 0.14901961],
#           [0.21176471, 0.14901961, 0.09803922],
#           [0.1764706 , 0.10588235, 0.05098039],
#           ...,
#           [0.3254902 , 0.27450982, 0.23921569],
#           [0.34117648, 0.2901961 , 0.25490198],
#           [0.7372549 , 0.69803923, 0.65882355]],
#
#          [[0.5294118 , 0.45882353, 0.40392157],
#           [0.8745098 , 0.8039216 , 0.7490196 ],
#           [0.6392157 , 0.5647059 , 0.50980395],
#           ...,
#           [0.3137255 , 0.24313726, 0.19607843],
#           [0.5176471 , 0.4627451 , 0.4117647 ],
#           [0.47843137, 0.43137255, 0.3764706 ]],
#
#          ...,
#
#          [[0.39607844, 0.3137255 , 0.3019608 ],
#           [0.36862746, 0.3019608 , 0.27058825],
#           [0.43529412, 0.39215687, 0.32156864],
#           ...,
#           [0.5529412 , 0.4862745 , 0.45490196],
#           [0.41568628, 0.34901962, 0.31764707],
#           [0.4       , 0.34509805, 0.3019608 ]],
#
#          [[0.36078432, 0.27450982, 0.23137255],
#           [0.69411767, 0.62352943, 0.5686275 ],
#           [0.29411766, 0.24705882, 0.16078432],
#           ...,
#           [0.4862745 , 0.41960785, 0.39215687],
#           [0.42745098, 0.37254903, 0.32941177],
#           [0.42745098, 0.38039216, 0.3254902 ]],
#
#          [[0.49411765, 0.40784314, 0.3529412 ],
#           [0.49411765, 0.41960785, 0.3529412 ],
#           [0.5176471 , 0.47058824, 0.3764706 ],
#           ...,
#           [0.43529412, 0.3764706 , 0.34901962],
#           [0.21568628, 0.16078432, 0.11764706],
#           [0.41960785, 0.37254903, 0.31764707]]],
#
#
#         ...,
#
#
#         [[[0.2901961 , 0.38431373, 0.33333334],
#           [0.11372549, 0.19607843, 0.16078432],
#           [0.41568628, 0.49019608, 0.4745098 ],
#           ...,
#           [0.2509804 , 0.3019608 , 0.26666668],
#           [0.10588235, 0.14117648, 0.12156863],
#           [0.10980392, 0.14509805, 0.1254902 ]],
#
#          [[0.1254902 , 0.20392157, 0.16078432],
#           [0.12156863, 0.2       , 0.16470589],
#           [0.35686275, 0.41960785, 0.41568628],
#           ...,
#           [0.11372549, 0.16470589, 0.13725491],
#           [0.3019608 , 0.3372549 , 0.31764707],
#           [0.13725491, 0.17254902, 0.15294118]],
#
#          [[0.27058825, 0.32156864, 0.28235295],
#           [0.41568628, 0.4745098 , 0.45490196],
#           [0.4745098 , 0.53333336, 0.5529412 ],
#           ...,
#           [0.1254902 , 0.17254902, 0.15686275],
#           [0.2627451 , 0.29803923, 0.28627452],
#           [0.12156863, 0.15686275, 0.14509805]],
#
#          ...,
#
#          [[0.27058825, 0.26666668, 0.32156864],
#           [0.6156863 , 0.6       , 0.654902  ],
#           [0.35686275, 0.30980393, 0.35686275],
#           ...,
#           [0.46666667, 0.42745098, 0.42352942],
#           [0.69803923, 0.6392157 , 0.61960787],
#           [0.5019608 , 0.44705883, 0.4117647 ]],
#
#          [[0.24313726, 0.25490198, 0.3137255 ],
#           [0.29803923, 0.30588236, 0.3647059 ],
#           [0.25882354, 0.25490198, 0.31764707],
#           ...,
#           [0.4627451 , 0.39215687, 0.3764706 ],
#           [0.33333334, 0.25490198, 0.2509804 ],
#           [0.49803922, 0.42745098, 0.42745098]],
#
#          [[0.19215687, 0.21568628, 0.2784314 ],
#           [0.28627452, 0.30980393, 0.37254903],
#           [0.3137255 , 0.33333334, 0.40784314],
#           ...,
#           [0.45882353, 0.3764706 , 0.35686275],
#           [0.68235296, 0.59607846, 0.6039216 ],
#           [0.6392157 , 0.5568628 , 0.5764706 ]]],
#
#
#         [[[0.6666667 , 0.6666667 , 0.6666667 ],
#           [0.2784314 , 0.2784314 , 0.2784314 ],
#           [0.48235294, 0.48235294, 0.48235294],
#           ...,
#           [0.16862746, 0.16862746, 0.16862746],
#           [0.14901961, 0.14901961, 0.14901961],
#           [0.79607844, 0.79607844, 0.79607844]],
#
#          [[0.34901962, 0.34901962, 0.34901962],
#           [0.33333334, 0.33333334, 0.33333334],
#           [0.52156866, 0.52156866, 0.52156866],
#           ...,
#           [0.15294118, 0.15294118, 0.15294118],
#           [0.15294118, 0.15294118, 0.15294118],
#           [0.8       , 0.8       , 0.8       ]],
#
#          [[0.35686275, 0.35686275, 0.35686275],
#           [0.33333334, 0.33333334, 0.33333334],
#           [0.5294118 , 0.5294118 , 0.5294118 ],
#           ...,
#           [0.19215687, 0.19215687, 0.19215687],
#           [0.10196079, 0.10196079, 0.10196079],
#           [0.8       , 0.8       , 0.8       ]],
#
#          ...,
#
#          [[0.35686275, 0.35686275, 0.35686275],
#           [0.24313726, 0.24313726, 0.24313726],
#           [0.27058825, 0.27058825, 0.27058825],
#           ...,
#           [0.16862746, 0.16862746, 0.16862746],
#           [0.01568628, 0.01568628, 0.01568628],
#           [0.8117647 , 0.8117647 , 0.8117647 ]],
#
#          [[0.3647059 , 0.3647059 , 0.3647059 ],
#           [0.18039216, 0.18039216, 0.18039216],
#           [0.1882353 , 0.1882353 , 0.1882353 ],
#           ...,
#           [0.00784314, 0.00784314, 0.00784314],
#           [0.03137255, 0.03137255, 0.03137255],
#           [0.79607844, 0.79607844, 0.79607844]],
#
#          [[0.3647059 , 0.3647059 , 0.3647059 ],
#           [0.19607843, 0.19607843, 0.19607843],
#           [0.12941177, 0.12941177, 0.12941177],
#           ...,
#           [0.11764706, 0.11764706, 0.11764706],
#           [0.10196079, 0.10196079, 0.10196079],
#           [0.8       , 0.8       , 0.8       ]]],
#
#
#         [[[0.01568628, 0.        , 0.        ],
#           [0.02352941, 0.01176471, 0.        ],
#           [0.08235294, 0.08235294, 0.03529412],
#           ...,
#           [0.06666667, 0.09411765, 0.03137255],
#           [0.        , 0.        , 0.        ],
#           [0.04705882, 0.04313726, 0.06666667]],
#
#          [[0.03529412, 0.01960784, 0.00784314],
#           [0.02352941, 0.01960784, 0.        ],
#           [0.05098039, 0.05882353, 0.01568628],
#           ...,
#           [0.00392157, 0.03529412, 0.        ],
#           [0.03921569, 0.04705882, 0.03529412],
#           [0.01176471, 0.01568628, 0.03137255]],
#
#          [[0.02352941, 0.03137255, 0.01960784],
#           [0.02745098, 0.03529412, 0.01568628],
#           [0.01176471, 0.01960784, 0.        ],
#           ...,
#           [0.05490196, 0.10196079, 0.04705882],
#           [0.03921569, 0.06666667, 0.03921569],
#           [0.01568628, 0.03529412, 0.01960784]],
#
#          ...,
#
#          [[0.7254902 , 0.8156863 , 0.7372549 ],
#           [0.60784316, 0.6784314 , 0.6156863 ],
#           [0.8627451 , 0.90588236, 0.88235295],
#           ...,
#           [0.6509804 , 0.53333336, 0.39215687],
#           [0.5568628 , 0.3882353 , 0.2627451 ],
#           [0.69803923, 0.5137255 , 0.39607844]],
#
#          [[0.80784315, 0.9843137 , 0.95686275],
#           [0.5529412 , 0.72156864, 0.69411767],
#           [0.53333336, 0.6862745 , 0.68235296],
#           ...,
#           [0.7019608 , 0.6392157 , 0.49803922],
#           [0.54901963, 0.4509804 , 0.32941177],
#           [0.7372549 , 0.62352943, 0.5058824 ]],
#
#          [[0.3254902 , 0.54509807, 0.5411765 ],
#           [0.5372549 , 0.75686276, 0.7529412 ],
#           [0.7921569 , 0.99215686, 0.99607843],
#           ...,
#           [0.68235296, 0.6431373 , 0.5019608 ],
#           [0.6901961 , 0.62352943, 0.5058824 ],
#           [0.6901961 , 0.60784316, 0.49411765]]]], dtype=float32),
#  array([[[[1.        , 0.98039216, 1.        ],
#           [1.        , 0.9882353 , 1.        ],
#           [1.        , 0.99607843, 1.        ],
#           ...,
#           [0.5058824 , 0.5176471 , 0.48235294],
#           [0.5058824 , 0.5176471 , 0.48235294],
#           [0.5058824 , 0.5176471 , 0.48235294]],
#
#          [[1.        , 0.9882353 , 1.        ],
#           [1.        , 0.99215686, 1.        ],
#           [1.        , 0.99607843, 1.        ],
#           ...,
#           [0.5058824 , 0.5176471 , 0.48235294],
#           [0.5058824 , 0.5176471 , 0.48235294],
#           [0.5058824 , 0.5176471 , 0.48235294]],
#
#          [[0.99607843, 1.        , 1.        ],
#           [1.        , 1.        , 1.        ],
#           [1.        , 0.99215686, 1.        ],
#           ...,
#           [0.5058824 , 0.5176471 , 0.48235294],
#           [0.5058824 , 0.5176471 , 0.48235294],
#           [0.5058824 , 0.5176471 , 0.48235294]],
#
#          ...,
#
#          [[0.3137255 , 0.00392157, 0.32156864],
#           [0.32156864, 0.00784314, 0.34117648],
#           [0.33333334, 0.        , 0.3647059 ],
#           ...,
#           [0.16862746, 0.23529412, 0.59607846],
#           [0.7647059 , 0.80784315, 1.        ],
#           [0.18039216, 0.21960784, 0.49803922]],
#
#          [[0.29411766, 0.00784314, 0.32941177],
#           [0.30980393, 0.        , 0.34901962],
#           [0.33333334, 0.        , 0.37254903],
#           ...,
#           [0.13333334, 0.20392157, 0.5882353 ],
#           [0.40784314, 0.43137255, 0.7764706 ],
#           [0.27058825, 0.2627451 , 0.5921569 ]],
#
#          [[0.29803923, 0.01568628, 0.34509805],
#           [0.30980393, 0.01176471, 0.35686275],
#           [0.3372549 , 0.        , 0.38431373],
#           ...,
#           [0.15686275, 0.23529412, 0.62352943],
#           [0.19215687, 0.19215687, 0.5686275 ],
#           [0.40784314, 0.38039216, 0.74509805]]],
#
#
#         [[[0.13725491, 0.19607843, 0.27058825],
#           [0.1254902 , 0.18431373, 0.25882354],
#           [0.11764706, 0.16862746, 0.24313726],
#           ...,
#           [0.01960784, 0.13725491, 0.24705882],
#           [0.03529412, 0.14117648, 0.25882354],
#           [0.04313726, 0.14901961, 0.26666668]],
#
#          [[0.12941177, 0.18039216, 0.25490198],
#           [0.11764706, 0.16862746, 0.23529412],
#           [0.10196079, 0.15294118, 0.22745098],
#           ...,
#           [0.02352941, 0.14117648, 0.2509804 ],
#           [0.03921569, 0.14509805, 0.2627451 ],
#           [0.04313726, 0.14901961, 0.26666668]],
#
#          [[0.11764706, 0.16078432, 0.23137255],
#           [0.10588235, 0.15294118, 0.21568628],
#           [0.08627451, 0.12941177, 0.2       ],
#           ...,
#           [0.03921569, 0.15686275, 0.26666668],
#           [0.04705882, 0.15294118, 0.26666668],
#           [0.04313726, 0.14901961, 0.2627451 ]],
#
#          ...,
#
#          [[0.01176471, 0.00784314, 0.03921569],
#           [0.00784314, 0.00392157, 0.03529412],
#           [0.01176471, 0.01568628, 0.03529412],
#           ...,
#           [0.02745098, 0.05098039, 0.10588235],
#           [0.05882353, 0.07058824, 0.12941177],
#           [0.04705882, 0.05882353, 0.11764706]],
#
#          [[0.01960784, 0.01568628, 0.03921569],
#           [0.00784314, 0.00392157, 0.02745098],
#           [0.00392157, 0.00392157, 0.03529412],
#           ...,
#           [0.01568628, 0.03137255, 0.06666667],
#           [0.01176471, 0.02352941, 0.05882353],
#           [0.01960784, 0.03137255, 0.06666667]],
#
#          [[0.00784314, 0.00392157, 0.02745098],
#           [0.01568628, 0.01176471, 0.03529412],
#           [0.        , 0.        , 0.02745098],
#           ...,
#           [0.00392157, 0.01568628, 0.04313726],
#           [0.01960784, 0.01960784, 0.05098039],
#           [0.01960784, 0.01960784, 0.05098039]]],
#
#
#         [[[0.18039216, 0.1254902 , 0.07450981],
#           [0.15294118, 0.09803922, 0.04705882],
#           [0.27450982, 0.21960784, 0.16862746],
#           ...,
#           [0.45490196, 0.3882353 , 0.35686275],
#           [0.39215687, 0.3137255 , 0.28627452],
#           [0.34117648, 0.2627451 , 0.23529412]],
#
#          [[0.21960784, 0.16470589, 0.11372549],
#           [0.16470589, 0.10980392, 0.05882353],
#           [0.23921569, 0.18431373, 0.13333334],
#           ...,
#           [0.5294118 , 0.4627451 , 0.43137255],
#           [0.41960785, 0.34509805, 0.31764707],
#           [0.39607844, 0.32156864, 0.29411766]],
#
#          [[0.15294118, 0.09019608, 0.03921569],
#           [0.16078432, 0.09803922, 0.04705882],
#           [0.23137255, 0.16862746, 0.11764706],
#           ...,
#           [0.3254902 , 0.25882354, 0.22745098],
#           [0.34117648, 0.27450982, 0.24313726],
#           [0.4627451 , 0.39607844, 0.3647059 ]],
#
#          ...,
#
#          [[0.39607844, 0.3137255 , 0.24705882],
#           [0.41960785, 0.34509805, 0.28627452],
#           [0.49019608, 0.40392157, 0.34901962],
#           ...,
#           [0.3529412 , 0.3019608 , 0.27058825],
#           [0.48235294, 0.42352942, 0.39607844],
#           [0.627451  , 0.5764706 , 0.54509807]],
#
#          [[0.48235294, 0.39215687, 0.3372549 ],
#           [0.48235294, 0.39607844, 0.34117648],
#           [0.62352943, 0.54901963, 0.49019608],
#           ...,
#           [0.4       , 0.34509805, 0.29411766],
#           [0.5529412 , 0.49019608, 0.4392157 ],
#           [0.5647059 , 0.50980395, 0.45882353]],
#
#          [[0.44705883, 0.35686275, 0.3019608 ],
#           [0.45882353, 0.37254903, 0.31764707],
#           [0.68235296, 0.60784316, 0.54901963],
#           ...,
#           [0.8352941 , 0.77254903, 0.7137255 ],
#           [0.59607846, 0.53333336, 0.4745098 ],
#           [0.50980395, 0.44705883, 0.3882353 ]]],
#
#
#         ...,
#
#
#         [[[0.3137255 , 0.39607844, 0.32941177],
#           [0.38431373, 0.45490196, 0.40784314],
#           [0.33333334, 0.38039216, 0.37254903],
#           ...,
#           [0.16862746, 0.20392157, 0.2       ],
#           [0.2       , 0.23921569, 0.20784314],
#           [0.12941177, 0.16862746, 0.1254902 ]],
#
#          [[0.27450982, 0.35686275, 0.29803923],
#           [0.4117647 , 0.49019608, 0.44313726],
#           [0.1882353 , 0.23529412, 0.22745098],
#           ...,
#           [0.21176471, 0.2509804 , 0.24705882],
#           [0.15294118, 0.19215687, 0.16078432],
#           [0.10196079, 0.14901961, 0.10980392]],
#
#          [[0.23921569, 0.3254902 , 0.27450982],
#           [0.21960784, 0.30588236, 0.25882354],
#           [0.16470589, 0.22352941, 0.20392157],
#           ...,
#           [0.21176471, 0.25882354, 0.24313726],
#           [0.14117648, 0.18431373, 0.16078432],
#           [0.20392157, 0.25490198, 0.22745098]],
#
#          ...,
#
#          [[0.23921569, 0.26666668, 0.3764706 ],
#           [0.15686275, 0.20392157, 0.30588236],
#           [0.1882353 , 0.2509804 , 0.34901962],
#           ...,
#           [0.47058824, 0.4117647 , 0.4       ],
#           [0.6       , 0.5411765 , 0.5294118 ],
#           [0.30588236, 0.24705882, 0.22745098]],
#
#          [[0.25882354, 0.29411766, 0.40784314],
#           [0.18431373, 0.23137255, 0.33333334],
#           [0.27450982, 0.3372549 , 0.42745098],
#           ...,
#           [0.42352942, 0.37254903, 0.34117648],
#           [0.5294118 , 0.4627451 , 0.43137255],
#           [0.26666668, 0.2       , 0.16078432]],
#
#          [[0.22745098, 0.27058825, 0.38039216],
#           [0.21568628, 0.27058825, 0.37254903],
#           [0.21176471, 0.27058825, 0.3529412 ],
#           ...,
#           [0.3254902 , 0.28627452, 0.23921569],
#           [0.44705883, 0.38039216, 0.34117648],
#           [0.25490198, 0.18431373, 0.13725491]]],
#
#
#         [[[0.99215686, 0.99215686, 0.99215686],
#           [1.        , 1.        , 1.        ],
#           [0.99607843, 0.99607843, 0.99607843],
#           ...,
#           [0.99607843, 0.99607843, 0.99607843],
#           [1.        , 1.        , 1.        ],
#           [0.99607843, 0.99607843, 0.99607843]],
#
#          [[0.9647059 , 0.9647059 , 0.9647059 ],
#           [0.92941177, 0.92941177, 0.92941177],
#           [0.8156863 , 0.8156863 , 0.8156863 ],
#           ...,
#           [0.80784315, 0.80784315, 0.80784315],
#           [0.99215686, 0.99215686, 0.99215686],
#           [1.        , 1.        , 1.        ]],
#
#          [[0.76862746, 0.76862746, 0.76862746],
#           [0.49803922, 0.49803922, 0.49803922],
#           [0.30980393, 0.30980393, 0.30980393],
#           ...,
#           [0.21176471, 0.21176471, 0.21176471],
#           [1.        , 1.        , 1.        ],
#           [0.99607843, 0.99607843, 0.99607843]],
#
#          ...,
#
#          [[0.6862745 , 0.6862745 , 0.6862745 ],
#           [0.34901962, 0.34901962, 0.34901962],
#           [0.21176471, 0.21176471, 0.21176471],
#           ...,
#           [0.20784314, 0.20784314, 0.20784314],
#           [1.        , 1.        , 1.        ],
#           [1.        , 1.        , 1.        ]],
#
#          [[0.72156864, 0.72156864, 0.72156864],
#           [0.41568628, 0.41568628, 0.41568628],
#           [0.44313726, 0.44313726, 0.44313726],
#           ...,
#           [0.80784315, 0.80784315, 0.80784315],
#           [0.99215686, 0.99215686, 0.99215686],
#           [1.        , 1.        , 1.        ]],
#
#          [[0.9372549 , 0.9372549 , 0.9372549 ],
#           [0.8627451 , 0.8627451 , 0.8627451 ],
#           [0.8392157 , 0.8392157 , 0.8392157 ],
#           ...,
#           [0.99215686, 0.99215686, 0.99215686],
#           [0.99607843, 0.99607843, 0.99607843],
#           [1.        , 1.        , 1.        ]]],
#
#
#         [[[0.03921569, 0.04705882, 0.03529412],
#           [0.08235294, 0.09019608, 0.07843138],
#           [0.01568628, 0.02352941, 0.01176471],
#           ...,
#           [0.        , 0.00784314, 0.        ],
#           [0.03137255, 0.05098039, 0.02352941],
#           [0.03529412, 0.05490196, 0.02745098]],
#
#          [[0.00392157, 0.01176471, 0.        ],
#           [0.        , 0.00784314, 0.        ],
#           [0.        , 0.00392157, 0.        ],
#           ...,
#           [0.03529412, 0.05490196, 0.02745098],
#           [0.0627451 , 0.08235294, 0.05490196],
#           [0.03137255, 0.05098039, 0.02352941]],
#
#          [[0.01960784, 0.02745098, 0.01568628],
#           [0.01960784, 0.02745098, 0.01568628],
#           [0.        , 0.00784314, 0.        ],
#           ...,
#           [0.01176471, 0.03137255, 0.00784314],
#           [0.02352941, 0.04313726, 0.01568628],
#           [0.01960784, 0.03921569, 0.01176471]],
#
#          ...,
#
#          [[0.36862746, 0.58431375, 0.56078434],
#           [0.31764707, 0.5411765 , 0.5137255 ],
#           [0.45882353, 0.7058824 , 0.6745098 ],
#           ...,
#           [0.6784314 , 0.63529414, 0.5176471 ],
#           [0.65882355, 0.62352943, 0.50980395],
#           [0.6745098 , 0.64705884, 0.53333336]],
#
#          [[0.2901961 , 0.5019608 , 0.5019608 ],
#           [0.37254903, 0.5686275 , 0.57254905],
#           [0.59607846, 0.76862746, 0.78039217],
#           ...,
#           [0.65882355, 0.6039216 , 0.49019608],
#           [0.67058825, 0.627451  , 0.50980395],
#           [0.6745098 , 0.6392157 , 0.5176471 ]],
#
#          [[0.14509805, 0.35686275, 0.3647059 ],
#           [0.13725491, 0.3254902 , 0.34117648],
#           [0.8156863 , 0.9411765 , 0.9843137 ],
#           ...,
#           [0.68235296, 0.627451  , 0.5137255 ],
#           [0.65882355, 0.6156863 , 0.49803922],
#           [0.6627451 , 0.61960787, 0.5019608 ]]]], dtype=float32))

# %%
from numpy.random import randint
def predict(model):
    #select random index
    ind = np.array([10])
    src_img , tar_img = x1[ind], x2[ind]
    #generate image from source
    gen_img = model.predict(src_img)
    return src_img, gen_img, tar_img

# %%
src1, gen1, tar1 = predict(model1)
# src2, gen2, tar2 = predict(model2)
# src3, gen3, tar3 = predict(model3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step

# %%
#plot all three images
def plot_img(src_img, gen_image, tar_img):
    plt.figure(figsize = (12, 10))
    plt.subplot(231)
    plt.title('LR Image')
    plt.imshow(src_img[0,:,:,:])
    plt.subplot(232)
    plt.title('Super Resolution')
    plt.imshow(gen_image[0,:,:,:])
    plt.subplot(233)
    plt.title('Original HR Image')
    plt.imshow(tar_img[0,:,:,:])

# %%
plot_img(src1, gen1, tar1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
